# %% [markdown]
# # Real-Time P2P Fraud Detection Demo\nLoad sample P2P payments and payment graph edges.

# %%
import pandas as pd\npayments = pd.read_csv('../data/sample/sample_p2p_payments.csv')\npayments.head()

# %%
edges = pd.read_csv('../data/sample/sample_payment_graph_edges.csv')\nedges.head()
